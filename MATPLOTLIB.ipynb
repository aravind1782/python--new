# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind1782/python--new/blob/module-4/MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6,3,4,2])
ypoints = np.array([5, 15,9,4,3])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["clad", "it", "cse", "phy","single variable","several varable"])
y = np.array([3, 8, 5, 10,7,7])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 8])
ypoints = np.array([6, 11])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 7, 10])
ypoints = np.array([5, 9, 15, 15])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 4, 6, 8, 2, 7])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["c language", "phy", "maths", "clad"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])


plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15 ])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([35, 25, 25, 15])
y = np.array([1,2,3,4])
colors = np.array(["red","green","blue","yellow"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt 
 
plt.scatter( 0 , 0 , s=10000 ,  facecolors='green', edgecolors='red' ) 
 
plt.xlim( -5 , 5 ) 
plt.ylim( -10 , 10 ) 
 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["c language", "phy", "maths", "clad"])
y = np.array([35, 25, 25, 15])

plt.bar(x, y, color = "rgb")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   import sys

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, marker = 'p')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, marker = 'd')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, 'p:g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, marker = 'D', ms = 10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'pink',mfc ='g')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, linestyle = 'dashed',ms=20,)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([35, 25, 25, 15])

plt.plot(ypoints, color = 'hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '2.05')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([35, 25, 25, 15])
y2 = np.array([3, 5, 2, 1])

plt.plot(y1)
plt.plot(y2)

plt.show()
