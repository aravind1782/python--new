# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind1782/python--new/blob/module-2/modul_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Create a function which accepts two inputs from the user and compute nCr
n = int(input("Enter the Value: "))
r = int(input("Enter the Value: "))
fact = i = 1 while i<=n:
fact = i*fact
i += 1 numerator = fact sub = n-r
fact = i = 1 while i<=sub:
fact = i*fact
i+= 1 denominator = fact fact = i = 1 while i<=r:
fact = i*fact
 i += 1
denominator=fact*denominator
comb=numerator/denominator
print("Combination (nCr) =", comb)
Enter the Value: 8
Enter the Value: 9
Combination (nCr) = 0.1111111111111111
## Recursive function to compute GCD of 2 numbers
def GCD(a,b): r=a%b
if(r==0): return b
else:
return GCD(b,r)
x=int(input("Enter the first number :"))
y=int(input("Enter the second number :"))
print("The GCD of two numbers is:", GCD(x,y))
Enter the first number :6 Enter the second number :18 The GCD of two numbers is: 6
## Recursive function to find product of two numbers
def prod(a,b): if(x==1):
return y elif(y==1):
return x else:
return x*y
x= int(input("Enter the first number :"))
y= int(input("Enter the second number :")) print("The product is:", prod(x,y))
Enter the first number :15 Enter the second number :4 The product is: 60
## Recursive function to generate Fibonacci series
def fib(n): if n <= 1:
return n else:
return(fib(n-1) + fib(n-2)) nelem=int(input("enter the number of elem")) if nelem <= 0:
print("enter a positive integer") else:
print("Fibonacci sequence:") for i in range(nelem):
  print(fib(i))
enter the number of elem8
Fibonacci sequence:
0
1
1 2 3 5 8 13
## Program to print
5th elements.
List=['Red', 'Green', 'White', 'Black', 'Pink', 'Yellow'] List = [x for (i,x) in enumerate(List) if i not in (0,4,5)] print(List)
['Green', 'White', 'Black']
## Program to get the difference between the two lists
def Diff(li1, li2):
return list(set(li1) - set(li2)) + list(set(li2) - set(li1))
li1 = ['5','10','15','20','25','30']
li2 = ['5','10','20','30']
print(Diff(li1, li2))
['25', '15']
## Program to find the second smallest number and second largest number in a list
def find_len(list1):
a specified list after removing the 0th, 4th and

length = len(list1)
list1.sort()
print("Second Largest element is:", list1[length-2]) print("Second Smallest element is:", list1[1])
list1=[12, 45, 2, 41, 31, 10, 8, 6, 4] Largest = find_len(list1)
Second Largest element is: 41 Second Smallest element is: 4
## Given a list of numbers of list, write a Python program to create a list of tuples having first element as the number and second element as the square of the number.
list=[5,8,12,20,30]
result = [(val, pow(val, 2)) for val in list] print(result)
[(5, 25), (8, 64), (12, 144), (20, 400), (30, 900)]
## Given list of tuples, remove all the tuples with length K
test_list = [(4, 5), (4, ), (8, 6, 7), (1, ), (3, 4, 6, 7)] K=2
res = [ele for ele in test_list if len(ele) != K] print("required list : " + str(res))
required list : [(4,), (8, 6, 7), (1,), (3, 4, 6, 7)]
## Program to generate and print a dictionary that contains a number (between 1 and n) in the form (x, x*x).
a=int(input("Input a number "))
b=dict()
for x in range(1,a+1): b[x]=x*x
print(b)
Input a number 9
{1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
## Program to remove a key from a dictionary
a={'name':'aravind', 'rollno':'1782', 'marks':'96'}
a.pop('rollno')
print(a)
{'name': 'aravind', 'marks': '96'}
## Program to get the maximum and minimum value in a dictionary
a={'p':289, 'q':74, 'r':6560}
maxval= max(a.keys(), key=(lambda k: a[k])) minval= min(a.keys(), key=(lambda k: a[k])) print('Max Value is ',a[maxval])
print('Min Value is ',a[minval])

Max Value is  6560
Min Value is  74
## Program to perform operations on string using unicodes ,splitting of string,accessing elements of string using locations
a="Hello, World"
print(a.split())
print(a[10])
['Hello,', 'World']
l
## Program for Counting occurrence of a certain element in a string, getting indexes that have matching elements
a="This is aravind"
x="i"
count=0
for i in a:
if i==x: count=count+1
print(count)
3
## Program for replacing one substring by another
a="Cat is my pet animal"
print(a.replace("Cat","Dog"))
Dog is my pet animal
## Program to Acronym generator for any user input
a="Indian Premier League" acr=""
for x in a:
if x.isupper(): acr=acr+x
print(acr)
IPL
## Python function that accepts a string and calculates the number of uppercase letters and lowercase letters
a="I like Football"
upp=0
low=0
for x in a:
if x.isupper(): upp=upp+1
elif x.islower(): low=low+1
else: pass

print("No of upper case letters are:",upp) print("No of lower case letters are:",low)
No of upper case letters are: 2 No of lower case letters are: 11
## Program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings
sample=['abc', 'xyz', 'aba', '1221']
count=0
for x in sample:
if len(x)>1 and x[0]==x[-1]: print("The required string is:",x) count=count+1
print("The number of strings with given conditions are:",count)
The required string is: aba
The required string is: 1221
The number of strings with given conditions are: 2
